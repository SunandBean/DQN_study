# %%
# 구현에 사용할 패키지 임포트
from environment import Environment
from multiprocessing import Process, Queue
#%matplotlib tk

# 각 환경 설정
# Environment(Double, Dueling, PER)

def RunEnv(Double, Dueling, PER):
    Env = Environment(Double, Dueling, PER)
    Env.run()

# %%
DQN = Process(target=RunEnv, args=(False, False, False))

#DDQN = Process(target=RunEnv, args=(True, False, False))
#DuelingDQN = Process(target=RunEnv, args=(False, True, False))
#PERDQN = Process(target=RunEnv, args=(False, False, True))

#DuelingDDQN = Process(target=RunEnv, args=(True, True, False))
#PERDDQN = Process(target=RunEnv, args=(True, False, True))
#PERDuelingDQN = Process(target=RunEnv, args=(False, True, True))

PERDuelingDDQN = Process(target=RunEnv, args=(True, True, True))

# %%
# Start
DQN.start()

#DDQN.start()
#DuelingDQN.start()
#PERDQN.start()

#DuelingDDQN.start()
#PERDDQN.start()
#PERDuelingDQN.start()

PERDuelingDDQN.start()

# Finish
DQN.join()

#DDQN.join()
#DuelingDQN.join()
#PERDQN.join()

#DuelingDDQN.join()
#PERDDQN.join()
#PERDuelingDQN.join()

PERDuelingDDQN.join()
# Out:
# Net(
#   (fc1): Linear(in_features=4, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=32, bias=True)
#   (fc3): Linear(in_features=32, out_features=2, bias=True)
# )
# Net(
#   (fc1): Linear(in_features=4, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=32, bias=True)
#   (fc3_adv): Linear(in_features=32, out_features=2, bias=True)
#   (fc3_v): Linear(in_features=32, out_features=1, bias=True)
# )
# DQN with Double : False, Dueling : False, PER : False
# 0 Episode: Finished after 16 steps : 최근 10 에피소드의 평균 단계 수 = 1.6
# DQN with Double : True, Dueling : True, PER : True
# 0 Episode: Finished after 15 steps : 최근 10 에피소드의 평균 단계 수 = 1.5
# DQN with Double : False, Dueling : False, PER : False
# 1 Episode: Finished after 16 steps : 최근 10 에피소드의 평균 단계 수 = 3.2
# DQN with Double : True, Dueling : True, PER : True
# 1 Episode: Finished after 14 steps : 최근 10 에피소드의 평균 단계 수 = 2.9
# DQN with Double : True, Dueling : True, PER : True
# 2 Episode: Finished after 12 steps : 최근 10 에피소드의 평균 단계 수 = 4.1
# DQN with Double : False, Dueling : False, PER : False
# 2 Episode: Finished after 23 steps : 최근 10 에피소드의 평균 단계 수 = 5.5
# DQN with Double : False, Dueling : False, PER : False
# 3 Episode: Finished after 14 steps : 최근 10 에피소드의 평균 단계 수 = 6.9
# DQN with Double : True, Dueling : True, PER : True
# 3 Episode: Finished after 16 steps : 최근 10 에피소드의 평균 단계 수 = 5.7
# DQN with Double : False, Dueling : False, PER : False
# 4 Episode: Finished after 16 steps : 최근 10 에피소드의 평균 단계 수 = 8.5
# DQN with Double : True, Dueling : True, PER : True
# 4 Episode: Finished after 12 steps : 최근 10 에피소드의 평균 단계 수 = 6.9
# DQN with Double : False, Dueling : False, PER : False
# 5 Episode: Finished after 14 steps : 최근 10 에피소드의 평균 단계 수 = 9.9
# DQN with Double : False, Dueling : False, PER : False
# DQN with Double : True, Dueling : True, PER : True
# 6 Episode: Finished after 19 steps : 최근 10 에피소드의 평균 단계 수 = 11.8
# 5 Episode: Finished after 15 steps : 최근 10 에피소드의 평균 단계 수 = 8.4
# DQN with Double : False, Dueling : False, PER : False
# 7 Episode: Finished after 17 steps : 최근 10 에피소드의 평균 단계 수 = 13.5
# DQN with Double : True, Dueling : True, PER : True
# 6 Episode: Finished after 15 steps : 최근 10 에피소드의 평균 단계 수 = 9.9
# DQN with Double : False, Dueling : False, PER : False
# 8 Episode: Finished after 16 steps : 최근 10 에피소드의 평균 단계 수 = 15.1
# DQN with Double : True, Dueling : True, PER : True
# 7 Episode: Finished after 11 steps : 최근 10 에피소드의 평균 단계 수 = 11.0
# DQN with Double : False, Dueling : False, PER : False
# 9 Episode: Finished after 15 steps : 최근 10 에피소드의 평균 단계 수 = 16.6
# DQN with Double : True, Dueling : True, PER : True
# 8 Episode: Finished after 11 steps : 최근 10 에피소드의 평균 단계 수 = 12.1
# DQN with Double : False, Dueling : False, PER : False
# 10 Episode: Finished after 19 steps : 최근 10 에피소드의 평균 단계 수 = 16.9
# DQN with Double : True, Dueling : True, PER : True
# 9 Episode: Finished after 10 steps : 최근 10 에피소드의 평균 단계 수 = 13.1
# DQN with Double : False, Dueling : False, PER : False
# DQN with Double : True, Dueling : True, PER : True
# 11 Episode: Finished after 26 steps : 최근 10 에피소드의 평균 단계 수 = 17.9
# 10 Episode: Finished after 10 steps : 최근 10 에피소드의 평균 단계 수 = 12.6
# DQN with Double : True, Dueling : True, PER : True
# 11 Episode: Finished after 12 steps : 최근 10 에피소드의 평균 단계 수 = 12.4
# DQN with Double : False, Dueling : False, PER : False
# 12 Episode: Finished after 25 steps : 최근 10 에피소드의 평균 단계 수 = 18.1
# DQN with Double : True, Dueling : True, PER : True
# 12 Episode: Finished after 12 steps : 최근 10 에피소드의 평균 단계 수 = 12.4
# DQN with Double : False, Dueling : False, PER : False
# 13 Episode: Finished after 25 steps : 최근 10 에피소드의 평균 단계 수 = 19.2
# DQN with Double : True, Dueling : True, PER : True
# 13 Episode: Finished after 10 steps : 최근 10 에피소드의 평균 단계 수 = 11.8
# DQN with Double : False, Dueling : False, PER : False
# 14 Episode: Finished after 25 steps : 최근 10 에피소드의 평균 단계 수 = 20.1
# DQN with Double : True, Dueling : True, PER : True
# 14 Episode: Finished after 16 steps : 최근 10 에피소드의 평균 단계 수 = 12.2
# DQN with Double : False, Dueling : False, PER : False
# 15 Episode: Finished after 26 steps : 최근 10 에피소드의 평균 단계 수 = 21.3
# DQN with Double : True, Dueling : True, PER : True
# 15 Episode: Finished after 16 steps : 최근 10 에피소드의 평균 단계 수 = 12.3
# DQN with Double : True, Dueling : True, PER : True
# 16 Episode: Finished after 14 steps : 최근 10 에피소드의 평균 단계 수 = 12.2
# DQN with Double : False, Dueling : False, PER : False
# 16 Episode: Finished after 44 steps : 최근 10 에피소드의 평균 단계 수 = 23.8
# DQN with Double : True, Dueling : True, PER : True
# 17 Episode: Finished after 13 steps : 최근 10 에피소드의 평균 단계 수 = 12.4
# DQN with Double : True, Dueling : True, PER : True
# 18 Episode: Finished after 14 steps : 최근 10 에피소드의 평균 단계 수 = 12.7
# DQN with Double : True, Dueling : True, PER : True
# 19 Episode: Finished after 12 steps : 최근 10 에피소드의 평균 단계 수 = 12.9
# DQN with Double : False, Dueling : False, PER : False
# 17 Episode: Finished after 57 steps : 최근 10 에피소드의 평균 단계 수 = 27.8
# DQN with Double : True, Dueling : True, PER : True
# 20 Episode: Finished after 13 steps : 최근 10 에피소드의 평균 단계 수 = 13.2
# DQN with Double : True, Dueling : True, PER : True
# 21 Episode: Finished after 17 steps : 최근 10 에피소드의 평균 단계 수 = 13.7
# DQN with Double : False, Dueling : False, PER : False
# 18 Episode: Finished after 49 steps : 최근 10 에피소드의 평균 단계 수 = 31.1
# DQN with Double : True, Dueling : True, PER : True
# 22 Episode: Finished after 15 steps : 최근 10 에피소드의 평균 단계 수 = 14.0
# DQN with Double : False, Dueling : False, PER : False
# 19 Episode: Finished after 34 steps : 최근 10 에피소드의 평균 단계 수 = 33.0
# DQN with Double : True, Dueling : True, PER : True
# 23 Episode: Finished after 17 steps : 최근 10 에피소드의 평균 단계 수 = 14.7
# DQN with Double : False, Dueling : False, PER : False
# 20 Episode: Finished after 43 steps : 최근 10 에피소드의 평균 단계 수 = 35.4
# DQN with Double : True, Dueling : True, PER : True
# 24 Episode: Finished after 20 steps : 최근 10 에피소드의 평균 단계 수 = 15.1
# DQN with Double : True, Dueling : True, PER : True
# 25 Episode: Finished after 15 steps : 최근 10 에피소드의 평균 단계 수 = 15.0
# DQN with Double : False, Dueling : False, PER : False
# 21 Episode: Finished after 40 steps : 최근 10 에피소드의 평균 단계 수 = 36.8
# DQN with Double : True, Dueling : True, PER : True
# 26 Episode: Finished after 20 steps : 최근 10 에피소드의 평균 단계 수 = 15.6
# DQN with Double : False, Dueling : False, PER : False
# 22 Episode: Finished after 37 steps : 최근 10 에피소드의 평균 단계 수 = 38.0
# DQN with Double : True, Dueling : True, PER : True
# 27 Episode: Finished after 21 steps : 최근 10 에피소드의 평균 단계 수 = 16.4
# DQN with Double : False, Dueling : False, PER : False
# 23 Episode: Finished after 93 steps : 최근 10 에피소드의 평균 단계 수 = 44.8
# DQN with Double : True, Dueling : True, PER : True
# 28 Episode: Finished after 56 steps : 최근 10 에피소드의 평균 단계 수 = 20.6
# DQN with Double : True, Dueling : True, PER : True
# 29 Episode: Finished after 10 steps : 최근 10 에피소드의 평균 단계 수 = 20.4
# DQN with Double : True, Dueling : True, PER : True
# 30 Episode: Finished after 10 steps : 최근 10 에피소드의 평균 단계 수 = 20.1
# DQN with Double : False, Dueling : False, PER : False
# DQN with Double : True, Dueling : True, PER : True
# 24 Episode: Finished after 78 steps : 최근 10 에피소드의 평균 단계 수 = 50.1
# 31 Episode: Finished after 10 steps : 최근 10 에피소드의 평균 단계 수 = 19.4
# DQN with Double : True, Dueling : True, PER : True
# 32 Episode: Finished after 10 steps : 최근 10 에피소드의 평균 단계 수 = 18.9
# DQN with Double : True, Dueling : True, PER : True
# 33 Episode: Finished after 9 steps : 최근 10 에피소드의 평균 단계 수 = 18.1
# DQN with Double : True, Dueling : True, PER : True
# 34 Episode: Finished after 9 steps : 최근 10 에피소드의 평균 단계 수 = 17.0
# DQN with Double : False, Dueling : False, PER : False
# 25 Episode: Finished after 73 steps : 최근 10 에피소드의 평균 단계 수 = 54.8
# DQN with Double : True, Dueling : True, PER : True
# 35 Episode: Finished after 9 steps : 최근 10 에피소드의 평균 단계 수 = 16.4
# DQN with Double : True, Dueling : True, PER : True
# 36 Episode: Finished after 9 steps : 최근 10 에피소드의 평균 단계 수 = 15.3
# DQN with Double : False, Dueling : False, PER : False
# 26 Episode: Finished after 31 steps : 최근 10 에피소드의 평균 단계 수 = 53.5
# DQN with Double : True, Dueling : True, PER : True
# 37 Episode: Finished after 10 steps : 최근 10 에피소드의 평균 단계 수 = 14.2
# DQN with Double : True, Dueling : True, PER : True
# 38 Episode: Finished after 9 steps : 최근 10 에피소드의 평균 단계 수 = 9.5
# DQN with Double : False, Dueling : False, PER : False
# 27 Episode: Finished after 40 steps : 최근 10 에피소드의 평균 단계 수 = 51.8
# DQN with Double : True, Dueling : True, PER : True
# 39 Episode: Finished after 8 steps : 최근 10 에피소드의 평균 단계 수 = 9.3
# DQN with Double : True, Dueling : True, PER : True
# 40 Episode: Finished after 10 steps : 최근 10 에피소드의 평균 단계 수 = 9.3
# DQN with Double : False, Dueling : False, PER : False
# 28 Episode: Finished after 33 steps : 최근 10 에피소드의 평균 단계 수 = 50.2
# DQN with Double : True, Dueling : True, PER : True
# 41 Episode: Finished after 9 steps : 최근 10 에피소드의 평균 단계 수 = 9.2
# DQN with Double : True, Dueling : True, PER : True
# 42 Episode: Finished after 9 steps : 최근 10 에피소드의 평균 단계 수 = 9.1
# DQN with Double : False, Dueling : False, PER : False
# 29 Episode: Finished after 40 steps : 최근 10 에피소드의 평균 단계 수 = 50.8
# DQN with Double : True, Dueling : True, PER : True
# 43 Episode: Finished after 9 steps : 최근 10 에피소드의 평균 단계 수 = 9.1
# DQN with Double : True, Dueling : True, PER : True
# 44 Episode: Finished after 9 steps : 최근 10 에피소드의 평균 단계 수 = 9.1
# DQN with Double : True, Dueling : True, PER : True
# 45 Episode: Finished after 8 steps : 최근 10 에피소드의 평균 단계 수 = 9.0
# DQN with Double : False, Dueling : False, PER : False
# 30 Episode: Finished after 51 steps : 최근 10 에피소드의 평균 단계 수 = 51.6
# DQN with Double : True, Dueling : True, PER : True
# 46 Episode: Finished after 10 steps : 최근 10 에피소드의 평균 단계 수 = 9.1
# DQN with Double : True, Dueling : True, PER : True
# 47 Episode: Finished after 10 steps : 최근 10 에피소드의 평균 단계 수 = 9.1
# DQN with Double : True, Dueling : True, PER : True
# 48 Episode: Finished after 9 steps : 최근 10 에피소드의 평균 단계 수 = 9.1
# DQN with Double : True, Dueling : True, PER : True
# 49 Episode: Finished after 10 steps : 최근 10 에피소드의 평균 단계 수 = 9.3
# DQN with Double : True, Dueling : True, PER : True
# 50 Episode: Finished after 10 steps : 최근 10 에피소드의 평균 단계 수 = 9.3
# DQN with Double : False, Dueling : False, PER : False
# 31 Episode: Finished after 113 steps : 최근 10 에피소드의 평균 단계 수 = 58.9
# DQN with Double : True, Dueling : True, PER : True
# 51 Episode: Finished after 10 steps : 최근 10 에피소드의 평균 단계 수 = 9.4
# DQN with Double : True, Dueling : True, PER : True
# 52 Episode: Finished after 10 steps : 최근 10 에피소드의 평균 단계 수 = 9.5
# DQN with Double : False, Dueling : False, PER : False
# 32 Episode: Finished after 55 steps : 최근 10 에피소드의 평균 단계 수 = 60.7
# DQN with Double : True, Dueling : True, PER : True
# 53 Episode: Finished after 26 steps : 최근 10 에피소드의 평균 단계 수 = 11.2
# DQN with Double : False, Dueling : False, PER : False
# 33 Episode: Finished after 48 steps : 최근 10 에피소드의 평균 단계 수 = 56.2
# DQN with Double : True, Dueling : True, PER : True
# 54 Episode: Finished after 20 steps : 최근 10 에피소드의 평균 단계 수 = 12.3
# DQN with Double : False, Dueling : False, PER : False
# 34 Episode: Finished after 41 steps : 최근 10 에피소드의 평균 단계 수 = 52.5
# DQN with Double : True, Dueling : True, PER : True
# 55 Episode: Finished after 29 steps : 최근 10 에피소드의 평균 단계 수 = 14.4
# DQN with Double : False, Dueling : False, PER : False
# 35 Episode: Finished after 44 steps : 최근 10 에피소드의 평균 단계 수 = 49.6
# DQN with Double : True, Dueling : True, PER : True
# 56 Episode: Finished after 23 steps : 최근 10 에피소드의 평균 단계 수 = 15.7
# DQN with Double : False, Dueling : False, PER : False
# 36 Episode: Finished after 39 steps : 최근 10 에피소드의 평균 단계 수 = 50.4
# DQN with Double : True, Dueling : True, PER : True
# 57 Episode: Finished after 23 steps : 최근 10 에피소드의 평균 단계 수 = 17.0
# DQN with Double : True, Dueling : True, PER : True
# 58 Episode: Finished after 25 steps : 최근 10 에피소드의 평균 단계 수 = 18.6
# DQN with Double : False, Dueling : False, PER : False
# 37 Episode: Finished after 40 steps : 최근 10 에피소드의 평균 단계 수 = 50.4
# DQN with Double : False, Dueling : False, PER : False
# 38 Episode: Finished after 48 steps : 최근 10 에피소드의 평균 단계 수 = 51.9
# DQN with Double : False, Dueling : False, PER : False
# 39 Episode: Finished after 43 steps : 최근 10 에피소드의 평균 단계 수 = 52.2
# DQN with Double : True, Dueling : True, PER : True
# 59 Episode: Finished after 55 steps : 최근 10 에피소드의 평균 단계 수 = 23.1
# DQN with Double : False, Dueling : False, PER : False
# 40 Episode: Finished after 41 steps : 최근 10 에피소드의 평균 단계 수 = 51.2
# DQN with Double : False, Dueling : False, PER : False
# 41 Episode: Finished after 35 steps : 최근 10 에피소드의 평균 단계 수 = 43.4
# DQN with Double : True, Dueling : True, PER : True
# 60 Episode: Finished after 35 steps : 최근 10 에피소드의 평균 단계 수 = 25.6
# DQN with Double : False, Dueling : False, PER : False
# 42 Episode: Finished after 64 steps : 최근 10 에피소드의 평균 단계 수 = 44.3
# DQN with Double : True, Dueling : True, PER : True
# 61 Episode: Finished after 44 steps : 최근 10 에피소드의 평균 단계 수 = 29.0
# DQN with Double : False, Dueling : False, PER : False
# 43 Episode: Finished after 36 steps : 최근 10 에피소드의 평균 단계 수 = 43.1
# DQN with Double : False, Dueling : False, PER : False
# 44 Episode: Finished after 53 steps : 최근 10 에피소드의 평균 단계 수 = 44.3
# DQN with Double : True, Dueling : True, PER : True
# 62 Episode: Finished after 51 steps : 최근 10 에피소드의 평균 단계 수 = 33.1
# DQN with Double : False, Dueling : False, PER : False
# 45 Episode: Finished after 41 steps : 최근 10 에피소드의 평균 단계 수 = 44.0
# DQN with Double : False, Dueling : False, PER : False
# 46 Episode: Finished after 113 steps : 최근 10 에피소드의 평균 단계 수 = 51.4
# DQN with Double : True, Dueling : True, PER : True
# 63 Episode: Finished after 74 steps : 최근 10 에피소드의 평균 단계 수 = 37.9
# DQN with Double : False, Dueling : False, PER : False
# 47 Episode: Finished after 51 steps : 최근 10 에피소드의 평균 단계 수 = 52.5
# DQN with Double : True, Dueling : True, PER : True
# 64 Episode: Finished after 61 steps : 최근 10 에피소드의 평균 단계 수 = 42.0
# DQN with Double : False, Dueling : False, PER : False
# 48 Episode: Finished after 200 steps : 최근 10 에피소드의 평균 단계 수 = 67.7
# DQN with Double : True, Dueling : True, PER : True
# 65 Episode: Finished after 75 steps : 최근 10 에피소드의 평균 단계 수 = 46.6
# DQN with Double : False, Dueling : False, PER : False
# 49 Episode: Finished after 84 steps : 최근 10 에피소드의 평균 단계 수 = 71.8
# DQN with Double : False, Dueling : False, PER : False
# 50 Episode: Finished after 44 steps : 최근 10 에피소드의 평균 단계 수 = 72.1
# DQN with Double : True, Dueling : True, PER : True
# 66 Episode: Finished after 91 steps : 최근 10 에피소드의 평균 단계 수 = 53.4
# DQN with Double : True, Dueling : True, PER : True
# 67 Episode: Finished after 62 steps : 최근 10 에피소드의 평균 단계 수 = 57.3
# DQN with Double : False, Dueling : False, PER : False
# 51 Episode: Finished after 200 steps : 최근 10 에피소드의 평균 단계 수 = 88.6
# DQN with Double : True, Dueling : True, PER : True
# 68 Episode: Finished after 41 steps : 최근 10 에피소드의 평균 단계 수 = 58.9
# DQN with Double : True, Dueling : True, PER : True
# 69 Episode: Finished after 47 steps : 최근 10 에피소드의 평균 단계 수 = 58.1
# DQN with Double : False, Dueling : False, PER : False
# 52 Episode: Finished after 200 steps : 최근 10 에피소드의 평균 단계 수 = 102.2
# DQN with Double : True, Dueling : True, PER : True
# 70 Episode: Finished after 42 steps : 최근 10 에피소드의 평균 단계 수 = 58.8
# DQN with Double : False, Dueling : False, PER : False
# 53 Episode: Finished after 76 steps : 최근 10 에피소드의 평균 단계 수 = 106.2
# DQN with Double : False, Dueling : False, PER : False
# 54 Episode: Finished after 200 steps : 최근 10 에피소드의 평균 단계 수 = 120.9
# DQN with Double : True, Dueling : True, PER : True
# 71 Episode: Finished after 93 steps : 최근 10 에피소드의 평균 단계 수 = 63.7
# DQN with Double : False, Dueling : False, PER : False
# 55 Episode: Finished after 139 steps : 최근 10 에피소드의 평균 단계 수 = 130.7
# DQN with Double : True, Dueling : True, PER : True
# 72 Episode: Finished after 62 steps : 최근 10 에피소드의 평균 단계 수 = 64.8
# DQN with Double : True, Dueling : True, PER : True
# 73 Episode: Finished after 40 steps : 최근 10 에피소드의 평균 단계 수 = 61.4
# DQN with Double : False, Dueling : False, PER : False
# 56 Episode: Finished after 200 steps : 최근 10 에피소드의 평균 단계 수 = 139.4
# DQN with Double : True, Dueling : True, PER : True
# 74 Episode: Finished after 44 steps : 최근 10 에피소드의 평균 단계 수 = 59.7
# DQN with Double : False, Dueling : False, PER : False
# 57 Episode: Finished after 119 steps : 최근 10 에피소드의 평균 단계 수 = 146.2
# DQN with Double : True, Dueling : True, PER : True
# 75 Episode: Finished after 52 steps : 최근 10 에피소드의 평균 단계 수 = 57.4
# DQN with Double : True, Dueling : True, PER : True
# 76 Episode: Finished after 36 steps : 최근 10 에피소드의 평균 단계 수 = 51.9
# DQN with Double : False, Dueling : False, PER : False
# 58 Episode: Finished after 200 steps : 최근 10 에피소드의 평균 단계 수 = 146.2
# DQN with Double : True, Dueling : True, PER : True
# 77 Episode: Finished after 87 steps : 최근 10 에피소드의 평균 단계 수 = 54.4
# DQN with Double : False, Dueling : False, PER : False
# 59 Episode: Finished after 200 steps : 최근 10 에피소드의 평균 단계 수 = 157.8
# DQN with Double : True, Dueling : True, PER : True
# 78 Episode: Finished after 39 steps : 최근 10 에피소드의 평균 단계 수 = 54.2
# DQN with Double : True, Dueling : True, PER : True
# 79 Episode: Finished after 54 steps : 최근 10 에피소드의 평균 단계 수 = 54.9
# DQN with Double : False, Dueling : False, PER : False
# 60 Episode: Finished after 200 steps : 최근 10 에피소드의 평균 단계 수 = 173.4
# DQN with Double : True, Dueling : True, PER : True
# 80 Episode: Finished after 44 steps : 최근 10 에피소드의 평균 단계 수 = 55.1
# DQN with Double : True, Dueling : True, PER : True
# 81 Episode: Finished after 52 steps : 최근 10 에피소드의 평균 단계 수 = 51.0
# DQN with Double : False, Dueling : False, PER : False
# 61 Episode: Finished after 190 steps : 최근 10 에피소드의 평균 단계 수 = 172.4
# DQN with Double : True, Dueling : True, PER : True
# 82 Episode: Finished after 72 steps : 최근 10 에피소드의 평균 단계 수 = 52.0
# DQN with Double : False, Dueling : False, PER : False
# 62 Episode: Finished after 200 steps : 최근 10 에피소드의 평균 단계 수 = 172.4
# DQN with Double : True, Dueling : True, PER : True
# 83 Episode: Finished after 57 steps : 최근 10 에피소드의 평균 단계 수 = 53.7
# DQN with Double : False, Dueling : False, PER : False
# 63 Episode: Finished after 200 steps : 최근 10 에피소드의 평균 단계 수 = 184.8
# DQN with Double : True, Dueling : True, PER : True
# 84 Episode: Finished after 53 steps : 최근 10 에피소드의 평균 단계 수 = 54.6
# DQN with Double : False, Dueling : False, PER : False
# 64 Episode: Finished after 200 steps : 최근 10 에피소드의 평균 단계 수 = 184.8
# DQN with Double : True, Dueling : True, PER : True
# 85 Episode: Finished after 105 steps : 최근 10 에피소드의 평균 단계 수 = 59.9
# DQN with Double : True, Dueling : True, PER : True
# 86 Episode: Finished after 57 steps : 최근 10 에피소드의 평균 단계 수 = 62.0
# DQN with Double : False, Dueling : False, PER : False
# 65 Episode: Finished after 200 steps : 최근 10 에피소드의 평균 단계 수 = 190.9
# DQN with Double : True, Dueling : True, PER : True
# 87 Episode: Finished after 59 steps : 최근 10 에피소드의 평균 단계 수 = 59.2
# DQN with Double : False, Dueling : False, PER : False
# 66 Episode: Finished after 200 steps : 최근 10 에피소드의 평균 단계 수 = 190.9
# ---- DQN with Double : False, Dueling : False, PER : False ----
# 10 에피소드 연속 성공
# ------------------------------------------------------
# DQN with Double : True, Dueling : True, PER : True
# 88 Episode: Finished after 72 steps : 최근 10 에피소드의 평균 단계 수 = 62.5
# DQN with Double : True, Dueling : True, PER : True
# 89 Episode: Finished after 124 steps : 최근 10 에피소드의 평균 단계 수 = 69.5
# DQN with Double : True, Dueling : True, PER : True
# 90 Episode: Finished after 155 steps : 최근 10 에피소드의 평균 단계 수 = 80.6
# DQN with Double : True, Dueling : True, PER : True
# 91 Episode: Finished after 96 steps : 최근 10 에피소드의 평균 단계 수 = 85.0
# DQN with Double : True, Dueling : True, PER : True
# 92 Episode: Finished after 142 steps : 최근 10 에피소드의 평균 단계 수 = 92.0
# DQN with Double : True, Dueling : True, PER : True
# 93 Episode: Finished after 126 steps : 최근 10 에피소드의 평균 단계 수 = 98.9
# DQN with Double : True, Dueling : True, PER : True
# 94 Episode: Finished after 57 steps : 최근 10 에피소드의 평균 단계 수 = 99.3
# DQN with Double : True, Dueling : True, PER : True
# 95 Episode: Finished after 200 steps : 최근 10 에피소드의 평균 단계 수 = 108.8
# DQN with Double : True, Dueling : True, PER : True
# 96 Episode: Finished after 200 steps : 최근 10 에피소드의 평균 단계 수 = 123.1
# DQN with Double : True, Dueling : True, PER : True
# 97 Episode: Finished after 200 steps : 최근 10 에피소드의 평균 단계 수 = 137.2
# DQN with Double : True, Dueling : True, PER : True
# 98 Episode: Finished after 175 steps : 최근 10 에피소드의 평균 단계 수 = 147.5
# DQN with Double : True, Dueling : True, PER : True
# 99 Episode: Finished after 200 steps : 최근 10 에피소드의 평균 단계 수 = 155.1
# DQN with Double : True, Dueling : True, PER : True
# 100 Episode: Finished after 200 steps : 최근 10 에피소드의 평균 단계 수 = 159.6
# DQN with Double : True, Dueling : True, PER : True
# 101 Episode: Finished after 138 steps : 최근 10 에피소드의 평균 단계 수 = 163.8
# DQN with Double : True, Dueling : True, PER : True
# 102 Episode: Finished after 153 steps : 최근 10 에피소드의 평균 단계 수 = 164.9
# DQN with Double : True, Dueling : True, PER : True
# 103 Episode: Finished after 200 steps : 최근 10 에피소드의 평균 단계 수 = 172.3
# DQN with Double : True, Dueling : True, PER : True
# 104 Episode: Finished after 123 steps : 최근 10 에피소드의 평균 단계 수 = 178.9

# %%
# 개별 실행할 때
#cartpole_env_Baseline = Environment(False, False, False)

#cartpole_env_DDQN = Environment(True, False, False)
#cartpole_env_DuelingDQN = Environment(False, True, False)
#cartpole_env_PERDQN = Environment(False, False, True)

#cartpole_env_DuelingDDQN = Environment(True, True, False)
#cartpole_env_PERDDQN = Environment(True, False, True)
#cartpole_env_PERDuelingDQN = Environment(False, True, True)

#cartpole_env_PERDuelingDDQN = Environment(True, True, True)

# %%
#cartpole_env_Baseline.run()

# %%
#cartpole_env_DDQN.run()

# %%
#cartpole_env_DuelingDQN.run()

# %%
#cartpole_env_PERDQN.run()

# %%
#cartpole_env_DuelingDDQN.run()

# %%
#cartpole_env_PERDDQN.run()

# %%
#cartpole_env_PERDuelingDQN.run()

# %%
#cartpole_env_PERDuelingDDQN.run()
